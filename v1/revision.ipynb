# %% [markdown]
# ## Stock price prediction

# %%
### importing the important libraries
import pandas as pd
import numpy as np
import seaborn as sns
import pandas_datareader as pdr
import matplotlib.pyplot as plt
# %matplotlib inline
import os
from dotenv import load_dotenv

# %%
### dealing with the api keys
load_dotenv('keys.txt')
key = os.getenv('key')

# %%
### loading the stock price by using the api and storing in form of a data frame
stock_price_aaple = pdr.get_data_tiingo('AAPL', api_key = key)
stock_price_aaple
# Out:
#                                    close     high     low     open     volume  \
# symbol date
# AAPL   2021-02-18 00:00:00+00:00  129.71  129.995  127.41  129.200   96856748
#        2021-02-19 00:00:00+00:00  129.87  130.710  128.80  130.240   87668834
#        2021-02-22 00:00:00+00:00  126.00  129.720  125.60  128.010  102886922
#        2021-02-23 00:00:00+00:00  125.86  126.710  118.39  123.760  158273022
#        2021-02-24 00:00:00+00:00  125.35  125.560  122.23  124.940  111039904
# ...                                  ...      ...     ...      ...        ...
#        2026-02-10 00:00:00+00:00  273.68  275.370  272.94  274.885   34376898
#        2026-02-11 00:00:00+00:00  275.50  280.180  274.45  274.695   51931283
#        2026-02-12 00:00:00+00:00  261.73  275.720  260.18  275.590   81077229
#        2026-02-13 00:00:00+00:00  255.78  262.230  255.45  262.010   56290673
#        2026-02-17 00:00:00+00:00  263.88  266.290  255.54  258.050   57949887
#
#                                     adjClose     adjHigh      adjLow  \
# symbol date
# AAPL   2021-02-18 00:00:00+00:00  126.349447  126.627063  124.109035
#        2021-02-19 00:00:00+00:00  126.505301  127.323538  125.463023
#        2021-02-22 00:00:00+00:00  122.735566  126.359187  122.345929
#        2021-02-23 00:00:00+00:00  122.599193  123.427171  115.322727
#        2021-02-24 00:00:00+00:00  122.102406  122.306966  119.063240
# ...                                      ...         ...         ...
#        2026-02-10 00:00:00+00:00  273.680000  275.370000  272.940000
#        2026-02-11 00:00:00+00:00  275.500000  280.180000  274.450000
#        2026-02-12 00:00:00+00:00  261.730000  275.720000  260.180000
#        2026-02-13 00:00:00+00:00  255.780000  262.230000  255.450000
#        2026-02-17 00:00:00+00:00  263.880000  266.290000  255.540000
#
#                                      adjOpen  adjVolume  divCash  splitFactor
# symbol date
# AAPL   2021-02-18 00:00:00+00:00  125.852660   96856748      0.0          1.0
#        2021-02-19 00:00:00+00:00  126.865715   87668834      0.0          1.0
#        2021-02-22 00:00:00+00:00  124.693491  102886922      0.0          1.0
#        2021-02-23 00:00:00+00:00  120.553600  158273022      0.0          1.0
#        2021-02-24 00:00:00+00:00  121.703029  111039904      0.0          1.0
# ...                                      ...        ...      ...          ...
#        2026-02-10 00:00:00+00:00  274.885000   34376898      0.0          1.0
#        2026-02-11 00:00:00+00:00  274.695000   51931283      0.0          1.0
#        2026-02-12 00:00:00+00:00  275.590000   81077229      0.0          1.0
#        2026-02-13 00:00:00+00:00  262.010000   56290673      0.0          1.0
#        2026-02-17 00:00:00+00:00  258.050000   57949887      0.0          1.0
#
# [1255 rows x 12 columns]
