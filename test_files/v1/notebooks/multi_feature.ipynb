# %% [markdown]
# ## Multi feature

# %%
### importing the libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
### setting up the system path and taking the functions from the src
import sys
sys.path.append('../')
from src.graphs.graphs_metrices import metrices, plot_predictions, plot_graphs_post_scaling

# %%
### loading the same 'AAPL' dataset as of 18-02
df = pd.read_csv('../stocks/apple-18-2.csv')
df.head()
# Out:
#   symbol                       date   close      high     low    open  \
# 0   AAPL  2021-02-19 00:00:00+00:00  129.87  130.7100  128.80  130.24
# 1   AAPL  2021-02-22 00:00:00+00:00  126.00  129.7200  125.60  128.01
# 2   AAPL  2021-02-23 00:00:00+00:00  125.86  126.7100  118.39  123.76
# 3   AAPL  2021-02-24 00:00:00+00:00  125.35  125.5600  122.23  124.94
# 4   AAPL  2021-02-25 00:00:00+00:00  120.99  126.4585  120.54  124.68
#
#       volume    adjClose     adjHigh      adjLow     adjOpen  adjVolume  \
# 0   87668834  126.505301  127.323538  125.463023  126.865715   87668834
# 1  102886922  122.735566  126.359187  122.345929  124.693491  102886922
# 2  158273022  122.599193  123.427171  115.322727  120.553600  158273022
# 3  111039904  122.102406  122.306966  119.063240  121.703029  111039904
# 4  144766924  117.855366  123.182187  117.417025  121.449765  144766924
#
#    divCash  splitFactor
# 0      0.0          1.0
# 1      0.0          1.0
# 2      0.0          1.0
# 3      0.0          1.0
# 4      0.0          1.0

# %%
### making the copy dataset
df_copy = df.copy()
df_copy.head()
# Out:
#   symbol                       date   close      high     low    open  \
# 0   AAPL  2021-02-19 00:00:00+00:00  129.87  130.7100  128.80  130.24
# 1   AAPL  2021-02-22 00:00:00+00:00  126.00  129.7200  125.60  128.01
# 2   AAPL  2021-02-23 00:00:00+00:00  125.86  126.7100  118.39  123.76
# 3   AAPL  2021-02-24 00:00:00+00:00  125.35  125.5600  122.23  124.94
# 4   AAPL  2021-02-25 00:00:00+00:00  120.99  126.4585  120.54  124.68
#
#       volume    adjClose     adjHigh      adjLow     adjOpen  adjVolume  \
# 0   87668834  126.505301  127.323538  125.463023  126.865715   87668834
# 1  102886922  122.735566  126.359187  122.345929  124.693491  102886922
# 2  158273022  122.599193  123.427171  115.322727  120.553600  158273022
# 3  111039904  122.102406  122.306966  119.063240  121.703029  111039904
# 4  144766924  117.855366  123.182187  117.417025  121.449765  144766924
#
#    divCash  splitFactor
# 0      0.0          1.0
# 1      0.0          1.0
# 2      0.0          1.0
# 3      0.0          1.0
# 4      0.0          1.0

# %%
### taking the 4 features ['close', 'open', 'low', 'open']
features_to_target = ['high', 'low', 'open']
main_feature = ['close']

# %%
### scaling the features
from sklearn.preprocessing import MinMaxScaler
scaler_for_rest = MinMaxScaler(feature_range = (0, 1))
df[features_to_target] = scaler_for_rest.fit_transform(df[features_to_target])
df.head()
# Out:
#   symbol                       date   close      high       low      open  \
# 0   AAPL  2021-02-19 00:00:00+00:00  129.87  0.061271  0.075349  0.067057
# 1   AAPL  2021-02-22 00:00:00+00:00  126.00  0.055386  0.056197  0.053718
# 2   AAPL  2021-02-23 00:00:00+00:00  125.86  0.037493  0.013047  0.028295
# 3   AAPL  2021-02-24 00:00:00+00:00  125.35  0.030656  0.036028  0.035353
# 4   AAPL  2021-02-25 00:00:00+00:00  120.99  0.035998  0.025914  0.033798
#
#       volume    adjClose     adjHigh      adjLow     adjOpen  adjVolume  \
# 0   87668834  126.505301  127.323538  125.463023  126.865715   87668834
# 1  102886922  122.735566  126.359187  122.345929  124.693491  102886922
# 2  158273022  122.599193  123.427171  115.322727  120.553600  158273022
# 3  111039904  122.102406  122.306966  119.063240  121.703029  111039904
# 4  144766924  117.855366  123.182187  117.417025  121.449765  144766924
#
#    divCash  splitFactor
# 0      0.0          1.0
# 1      0.0          1.0
# 2      0.0          1.0
# 3      0.0          1.0
# 4      0.0          1.0

# %%
### separately targeting the scaler for the feature 'close'
scaler_for_close = MinMaxScaler(feature_range = (0, 1))
df[main_feature] = scaler_for_close.fit_transform(df[main_feature])
df.head()
# Out:
#   symbol                       date     close      high       low      open  \
# 0   AAPL  2021-02-19 00:00:00+00:00  0.079550  0.061271  0.075349  0.067057
# 1   AAPL  2021-02-22 00:00:00+00:00  0.056763  0.055386  0.056197  0.053718
# 2   AAPL  2021-02-23 00:00:00+00:00  0.055938  0.037493  0.013047  0.028295
# 3   AAPL  2021-02-24 00:00:00+00:00  0.052935  0.030656  0.036028  0.035353
# 4   AAPL  2021-02-25 00:00:00+00:00  0.027263  0.035998  0.025914  0.033798
#
#       volume    adjClose     adjHigh      adjLow     adjOpen  adjVolume  \
# 0   87668834  126.505301  127.323538  125.463023  126.865715   87668834
# 1  102886922  122.735566  126.359187  122.345929  124.693491  102886922
# 2  158273022  122.599193  123.427171  115.322727  120.553600  158273022
# 3  111039904  122.102406  122.306966  119.063240  121.703029  111039904
# 4  144766924  117.855366  123.182187  117.417025  121.449765  144766924
#
#    divCash  splitFactor
# 0      0.0          1.0
# 1      0.0          1.0
# 2      0.0          1.0
# 3      0.0          1.0
# 4      0.0          1.0

# %%
### updating the features_to_target list
features_to_target.insert(0, main_feature[0])
features_to_target
# Out:
# ['close', 'high', 'low', 'open']

# %%
### checking for the features that were targeted only
plot_graphs_post_scaling(df, df_copy, features_to_target)
# Out:
# feature : close
# feature : high
# feature : low
# feature : open

# %%
### checking the length of the df
len(df)
# Out:
# 1255

# %%
### checking the list again
features_to_target
# Out:
# ['close', 'high', 'low', 'open']

# %%
### creating the two sequences X and y for 90 days
### for the y say our target feature is 'close' 
X, y = [], []
days = 90

for i in range (len(df) - days) : 

    X.append(df[features_to_target][i : i + days])
    y.append(df[features_to_target[0]][i + days])

X = np.array(X)
y = np.array(y)

# %%
### checking the X and y
X
# Out:
# array([[[0.07955014, 0.06127149, 0.07534861, 0.06705749],
#         [0.05676264, 0.05538623, 0.05619726, 0.05371777],
#         [0.05593829, 0.03749267, 0.01304686, 0.02829455],
#         ...,
#         [0.10039451, 0.08463418, 0.10006583, 0.09224143],
#         [0.09862804, 0.08017565, 0.09934766, 0.08631932],
#         [0.1084614 , 0.08823073, 0.10257945, 0.08602022]],
#
#        [[0.05676264, 0.05538623, 0.05619726, 0.05371777],
#         [0.05593829, 0.03749267, 0.01304686, 0.02829455],
#         [0.05293529, 0.03065625, 0.03602849, 0.03535323],
#         ...,
#         [0.09862804, 0.08017565, 0.09934766, 0.08631932],
#         [0.1084614 , 0.08823073, 0.10257945, 0.08602022],
#         [0.11758818, 0.09563189, 0.10856425, 0.09433511]],
#
#        [[0.05593829, 0.03749267, 0.01304686, 0.02829455],
#         [0.05293529, 0.03065625, 0.03602849, 0.03535323],
#         [0.02726256, 0.03599757, 0.02591418, 0.03379793],
#         ...,
#         [0.1084614 , 0.08823073, 0.10257945, 0.08602022],
#         [0.11758818, 0.09563189, 0.10856425, 0.09433511],
#         [0.12129777, 0.10110102, 0.11766114, 0.10253036]],
#
#        ...,
#
#        [[0.82629689, 0.82433394, 0.83092944, 0.83124963],
#         [0.82506035, 0.81440628, 0.83320366, 0.82416103],
#         [0.83436378, 0.82106435, 0.83727333, 0.82245618],
#         ...,
#         [0.9263381 , 0.92123265, 0.93799749, 0.93231441],
#         [0.9370547 , 0.94982668, 0.94703453, 0.93117784],
#         [0.85597362, 0.92331329, 0.86163146, 0.93653167]],
#
#        [[0.82506035, 0.81440628, 0.83320366, 0.82416103],
#         [0.83436378, 0.82106435, 0.83727333, 0.82245618],
#         [0.81069305, 0.8179731 , 0.81949847, 0.83014297],
#         ...,
#         [0.9370547 , 0.94982668, 0.94703453, 0.93117784],
#         [0.85597362, 0.92331329, 0.86163146, 0.93653167],
#         [0.82093859, 0.84311921, 0.83332336, 0.855297  ]],
#
#        [[0.83436378, 0.82106435, 0.83727333, 0.82245618],
#         [0.81069305, 0.8179731 , 0.81949847, 0.83014297],
#         [0.75905317, 0.80834268, 0.76479741, 0.81300473],
#         ...,
#         [0.85597362, 0.92331329, 0.86163146, 0.93653167],
#         [0.82093859, 0.84311921, 0.83332336, 0.855297  ],
#         [0.86863334, 0.86725472, 0.83386199, 0.83160854]]])

# %%
### checking y
y
# Out:
# array([0.11758818, 0.12129777, 0.12312312, ..., 0.82093859, 0.86863334,
#        0.87140081])

# %%
### for the verification the value of 90th index of closing price at df['close'] should match the value
df['close'][90]
# Out:
# 0.11758817641170594

# %%
### for the verification the value of 91th index of closing price at df['close'] should match the value
df['close'][91]
# Out:
# 0.1212977683565919

# %%
### checking the shape of the X and y
print(f"{X.shape} :: {y.shape}")
# Out:
# (1165, 90, 4) :: (1165,)

# %%
### reshaping the y
y = y.reshape(-1, 1)
y.shape
# Out:
# (1165, 1)

# %%
### checking the y as well
y
# Out:
# array([[0.11758818],
#        [0.12129777],
#        [0.12312312],
#        ...,
#        [0.82093859],
#        [0.86863334],
#        [0.87140081]])

# %%
### checking the shape of the X and y
print(f"{X.shape} :: {y.shape}")
# Out:
# (1165, 90, 4) :: (1165, 1)

# %%
### creating train and test sequence now (test_size = 0.80)
test_size = int(len(df) * 0.80)
X_train, X_test = X[:test_size], X[test_size:]
y_train, y_test = y[:test_size], y[test_size:]

# %%
### checking the shape of the X_train, X_test, y_train and y_test
print(f"{X_train.shape} :: {y_train.shape} \n{X_test.shape} :: {y_test.shape}")
# Out:
# (1004, 90, 4) :: (1004, 1)
# (161, 90, 4) :: (161, 1)

# %%
### importing the libraries for the LSTM model
import tensorflow
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, Bidirectional

# %%
### building a sequential model
model = Sequential([
    LSTM(50, return_sequences = True, input_shape = (days, 4)),
    Dropout(0.25),
    Bidirectional(LSTM(100)),
    Dropout(0.33),
    Dense(1, activation = 'linear')
])
model.compile(optimizer = 'adam', loss = 'mean_squared_error', metrics = ['mse'])
# Out:
# c:\Users\lenovo\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
### checking the model summary
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 90, 50)         │        11,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 90, 50)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ (None, 200)            │       120,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 200)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │           201 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 132,001 (515.63 KB)
#  Trainable params: 132,001 (515.63 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
### training the model
model.fit(X_train, y_train, batch_size = 32, epochs = 50, verbose = 1)
# Out:
# Epoch 1/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 47ms/step - loss: 0.0618 - mse: 0.0618
# Epoch 2/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.0045 - mse: 0.0045
# Epoch 3/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0038 - mse: 0.0038
# Epoch 4/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0030 - mse: 0.0030
# Epoch 5/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0033 - mse: 0.0033
# Epoch 6/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0033 - mse: 0.0033
# Epoch 7/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 0.0026 - mse: 0.0026
# Epoch 8/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0031 - mse: 0.0031
# Epoch 9/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0025 - mse: 0.0025
# Epoch 10/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 0.0028 - mse: 0.0028
# Epoch 11/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 0.0024 - mse: 0.0024
# Epoch 12/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0024 - mse: 0.0024
# Epoch 13/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0026 - mse: 0.0026
# Epoch 14/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0024 - mse: 0.0024
# Epoch 15/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 0.0024 - mse: 0.0024
# Epoch 16/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - loss: 0.0027 - mse: 0.0027
# Epoch 17/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0024 - mse: 0.0024
# Epoch 18/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0020 - mse: 0.0020
# Epoch 19/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0018 - mse: 0.0018
# Epoch 20/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0020 - mse: 0.0020
# Epoch 21/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0019 - mse: 0.0019
# Epoch 22/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0021 - mse: 0.0021
# Epoch 23/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0020 - mse: 0.0020
# Epoch 24/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0018 - mse: 0.0018
# Epoch 25/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0018 - mse: 0.0018
# Epoch 26/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0017 - mse: 0.0017
# Epoch 27/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0019 - mse: 0.0019
# Epoch 28/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0020 - mse: 0.0020
# Epoch 29/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0017 - mse: 0.0017
# Epoch 30/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0017 - mse: 0.0017
# Epoch 31/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0019 - mse: 0.0019
# Epoch 32/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0016 - mse: 0.0016
# Epoch 33/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0020 - mse: 0.0020
# Epoch 34/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 0.0014 - mse: 0.0014
# Epoch 35/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0019 - mse: 0.0019
# Epoch 36/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 0.0016 - mse: 0.0016
# Epoch 37/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0014 - mse: 0.0014
# Epoch 38/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0016 - mse: 0.0016
# Epoch 39/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0015 - mse: 0.0015
# Epoch 40/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0015 - mse: 0.0015
# Epoch 41/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0016 - mse: 0.0016
# Epoch 42/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0015 - mse: 0.0015
# Epoch 43/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0015 - mse: 0.0015
# Epoch 44/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 45/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - loss: 0.0015 - mse: 0.0015
# Epoch 46/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0015 - mse: 0.0015
# Epoch 47/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 0.0014 - mse: 0.0014
# Epoch 48/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0013 - mse: 0.0013
# Epoch 49/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0014 - mse: 0.0014
# Epoch 50/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 0.0013 - mse: 0.0013

# %%
### predicting on the y_test which is technically df['close]
y_pred = model.predict(X_test)
y_pred
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step
# array([[0.5063034 ],
#        [0.50977045],
#        [0.51992965],
#        [0.534774  ],
#        [0.5507913 ],
#        [0.5589465 ],
#        [0.5607195 ],
#        [0.55985445],
#        [0.5605667 ],
#        [0.5607627 ],
#        [0.5574465 ],
#        [0.55463177],
#        [0.5536298 ],
#        [0.5536062 ],
#        [0.5548832 ],
#        [0.5592019 ],
#        [0.5651058 ],
#        [0.5704805 ],
#        [0.5742774 ],
#        [0.57658035],
#        [0.57754564],
#        [0.57472736],
#        [0.5674369 ],
#        [0.5581009 ],
#        [0.5454176 ],
#        [0.53335667],
#        [0.5244885 ],
#        [0.52991515],
#        [0.5538079 ],
#        [0.58713776],
#        [0.6171705 ],
#        [0.64029783],
#        [0.6602271 ],
#        [0.6733675 ],
#        [0.6781534 ],
#        [0.6780204 ],
#        [0.6744536 ],
#        [0.66553056],
#        [0.6537213 ],
#        [0.64798945],
#        [0.6461961 ],
#        [0.64730155],
#        [0.6529179 ],
#        [0.6616144 ],
#        [0.6700203 ],
#        [0.67038125],
#        [0.68206644],
#        [0.6961039 ],
#        [0.70817554],
#        [0.71284646],
#        [0.70840555],
#        [0.6905631 ],
#        [0.67538315],
#        [0.6711113 ],
#        [0.6795383 ],
#        [0.69176966],
#        [0.70361507],
#        [0.710892  ],
#        [0.723061  ],
#        [0.749001  ],
#        [0.77456886],
#        [0.78781265],
#        [0.7967087 ],
#        [0.8014703 ],
#        [0.8017576 ],
#        [0.8010448 ],
#        [0.80252707],
#        [0.80532944],
#        [0.80783385],
#        [0.8102656 ],
#        [0.811365  ],
#        [0.8136349 ],
#        [0.8109249 ],
#        [0.7944781 ],
#        [0.7801528 ],
#        [0.769877  ],
#        [0.76837146],
#        [0.766334  ],
#        [0.7707902 ],
#        [0.7923338 ],
#        [0.8173463 ],
#        [0.82734245],
#        [0.83126986],
#        [0.8361421 ],
#        [0.8491908 ],
#        [0.8630424 ],
#        [0.8724769 ],
#        [0.8808963 ],
#        [0.88725114],
#        [0.8848827 ],
#        [0.8829182 ],
#        [0.881393  ],
#        [0.8812973 ],
#        [0.8801408 ],
#        [0.8805574 ],
#        [0.8881577 ],
#        [0.8961971 ],
#        [0.9011808 ],
#        [0.9007191 ],
#        [0.891291  ],
#        [0.88313067],
#        [0.8780822 ],
#        [0.87610745],
#        [0.8780855 ],
#        [0.88962126],
#        [0.9049809 ],
#        [0.91739047],
#        [0.92513674],
#        [0.9333189 ],
#        [0.94698554],
#        [0.956248  ],
#        [0.9536457 ],
#        [0.94564617],
#        [0.93647295],
#        [0.9304733 ],
#        [0.92862934],
#        [0.92706764],
#        [0.9279574 ],
#        [0.92419946],
#        [0.9174624 ],
#        [0.9113718 ],
#        [0.9039798 ],
#        [0.9017913 ],
#        [0.89997387],
#        [0.89870304],
#        [0.9018868 ],
#        [0.9054317 ],
#        [0.90728956],
#        [0.9075022 ],
#        [0.90575933],
#        [0.9022196 ],
#        [0.89291656],
#        [0.87770575],
#        [0.8616713 ],
#        [0.8454197 ],
#        [0.83622617],
#        [0.83298844],
#        [0.83414155],
#        [0.83446753],
#        [0.83338386],
#        [0.82773286],
#        [0.8071101 ],
#        [0.789611  ],
#        [0.7806587 ],
#        [0.7740432 ],
#        [0.7815218 ],
#        [0.80081075],
#        [0.8124472 ],
#        [0.8197786 ],
#        [0.82210094],
#        [0.83769125],
#        [0.85858   ],
#        [0.8838734 ],
#        [0.9029517 ],
#        [0.9174667 ],
#        [0.91879004],
#        [0.91508716],
#        [0.9143848 ],
#        [0.8938228 ],
#        [0.8626997 ],
#        [0.8459807 ]], dtype=float32)

# %%
### inverse scaling the y_test and y_pred
y_test = scaler_for_close.inverse_transform(y_test)
y_pred = scaler_for_close.inverse_transform(y_pred)

# %%
### for the comparison plotting the graphs and the metrices
metrices(y_test, y_pred)
# Out:
# MAE : 4.582546117557503
# MSE : 34.94423602535313
# RMSE : 5.9113649883384065

# %%
### plotting out the things
plot_predictions(y_test, y_pred)
